# %% [markdown]
# # Data Sciences Project

# %%
#!pip install selenium


import bs4
from bs4 import BeautifulSoup

import pandas as pd
import scipy as sc
import numpy as np


import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

import time

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns



import sklearn
from sklearn import linear_model, metrics, preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import r2_score, f1_score

# %% [markdown]
# ## Functions

# %%
def addData(arr,data):
    try:
        arr.append(data.find_element(By.CLASS_NAME,"value").text)
    except:
        arr.append(np.nan)

# %%
def addCTBar(arr,data):
    try:
        arr.append(data.get_attribute("ct:value"))
    except:
        arr.append(np.nan)

# %%
def addText(arr,data):
    try:
        arr.append(data.text)
    except:
        arr.append(np.nan)

# %%
def is_In_List(arr,word):
    for t in range(len(arr)):
        if (arr[t] == word):
            return 1
    return 0

# %% [markdown]
# ## Crawling

# %%
PATH = "\chromedriver.exe"
driver = webdriver.Chrome()

driver.get("https://anilist.co/search/manga?format=NOVEL")

time.sleep(3)

# %%
for j in range(5):
    driver.execute_script("window.scrollTo(0," + str(j * 1000) + ");")
    time.sleep(2)
    
links = driver.find_elements(By.CLASS_NAME,"media-card")
link_list = [elem.find_element(By.CLASS_NAME,"cover").get_attribute('href') for elem in links]
# Out:
# ['https://anilist.co/manga/94970/Youkoso-Jitsuryoku-Shijou-Shugi-no-Kyoushitsu-e/', 'https://anilist.co/manga/98361/Mikkakan-no-Koufuku/', 'https://anilist.co/manga/85470/Mushoku-Tensei-Isekai-Ittara-Honki-Dasu/', 'https://anilist.co/manga/85134/Utsuro-no-Hako-to-Zero-no-Maria/', 'https://anilist.co/manga/85737/ReZero-kara-Hajimeru-Isekai-Seikatsu/', 'https://anilist.co/manga/70171/Yahari-Ore-no-Seishun-Love-Come-wa-Machigatteiru/', 'https://anilist.co/manga/44893/Bakemonogatari/', 'https://anilist.co/manga/39115/Ookami-to-Koushinryou/', 'https://anilist.co/manga/78399/No-Game-No-Life/', 'https://anilist.co/manga/85976/Overlord/', 'https://anilist.co/manga/86238/Kono-Subarashii-Sekai-ni-Shukufuku-wo/', 'https://anilist.co/manga/51479/Sword-Art-Online/', 'https://anilist.co/manga/98610/86-Eighty-Six/', 'https://anilist.co/manga/86355/Tensei-Shitara-Slime-Datta-Ken/', 'https://anilist.co/manga/85743/Tate-no-Yuusha-no-Nariagari/', 'https://anilist.co/manga/115166/Youkoso-Jitsuryoku-Shij
# ...

# %%
html_file = "https://anilist.co/manga/94970/Youkoso-Jitsuryoku-Shijou-Shugi-no-Kyoushitsu-e/"
tempdrive = webdriver.Chrome()
tempdrive.get(html_file)
time.sleep(2)

dataset = tempdrive.find_elements(By.CLASS_NAME,"data-set")
data_list = [elem.find_element(By.CLASS_NAME,"value").text for elem in dataset]
print(data_list)
tempdrive.quit()
# Out:
# ['Light Novel', '110', '14', 'Finished', 'May 25, 2015', 'Sep 25, 2019', '88%', '88%', '27499', '3088', 'Original', 'Drama\nMystery\nPsychological', 'Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e', 'Classroom of the Elite', 'ようこそ実力至上主義の教室へ', 'Youjitsu\nYou-Zitsu\nขอต้อนรับสู่ห้องเรียนนิยม (เฉพาะ) ยอดคน\nChào mừng đến lớp học đề cao thực lực']

# %%
#Class data set
format_ = []
chap_ = []
vol_ = []
status_ = []
start_ = []
end_ = []
avg_score_ = []
mean_score_ = []
pop_ = []
favs_ = []
source_ = []
genres_ = []
name_romaj_ = []
name_eng_ = []
name_native_ = []
name_synon_ = []

#Class ct-bar
rating_10 = []
rating_20 = []
rating_30 = []
rating_40 = []
rating_50 = []
rating_60 = []
rating_70 = []
rating_80 = []
rating_90 = []
rating_100 = []

#Class Rankings Rated
rated_rank = []
popul_rank = []

#Class tag
tags_ = []

#Class Relations
cell1_role = []
cell1_type = []
cell2_role = []
cell2_type = []

tempdrive = webdriver.Chrome()


for k in link_list:
    tempdrive.get(link_list[k])
    time.sleep(1)
    dataset = tempdrive.find_elements(By.CLASS_NAME,"data-set")
    
    format_.append(dataset[0].find_element(By.CLASS_NAME,"value").text)
    chap_.append(dataset[1].find_element(By.CLASS_NAME,"value").text)
    vol_.append(dataset[2].find_element(By.CLASS_NAME,"value").text)
    status_.append(dataset[3].find_element(By.CLASS_NAME,"value").text)
    start_.append(dataset[4].find_element(By.CLASS_NAME,"value").text)
    end_.append(dataset[5].find_element(By.CLASS_NAME,"value").text)
    avg_score_.append(dataset[6].find_element(By.CLASS_NAME,"value").text)
    mean_score_.append(dataset[7].find_element(By.CLASS_NAME,"value").text)
    pop_.append(dataset[8].find_element(By.CLASS_NAME,"value").text)
    favs_.append(dataset[9].find_element(By.CLASS_NAME,"value").text)
    source_.append(dataset[10].find_element(By.CLASS_NAME,"value").text)
    genres_.append(dataset[11].find_element(By.CLASS_NAME,"value").text)
    name_romaj_.append(dataset[12].find_element(By.CLASS_NAME,"value").text)
    name_eng_.append(dataset[13].find_element(By.CLASS_NAME,"value").text)
    name_native_.append(dataset[14].find_element(By.CLASS_NAME,"value").text)
    name_synon_.append(dataset[15].find_element(By.CLASS_NAME,"value").text)

# %%
    tempdrive = webdriver.Chrome()
    tempdrive.get("https://anilist.co/manga/94970/Youkoso-Jitsuryoku-Shijou-Shugi-no-Kyoushitsu-e/")
    time.sleep(1)
    
    try:
        dataset = tempdrive.find_elements(By.CLASS_NAME,"data-set")
    except:
        dataset = np.nan
        
    try:
        ctbar = tempdrive.find_element(By.CLASS_NAME,"grid-section-wrap").find_elements(By.TAG_NAME,"g")[2].find_elements(By.CLASS_NAME,"ct-bar")#.get_attribute("ct:value")
    except:
        ctbar = np.nan
        
    try:
        ranku = tempdrive.find_element(By.CLASS_NAME,"rankings").find_elements(By.CLASS_NAME,"rank-text")
    except:
        ranku = np.nan
    
    try:
        tagstart = tempdrive.find_elements(By.CLASS_NAME,"tag")
    except:
        tagstart = np.nan  
    try:
        tagspoilclick = tempdrive.find_element(By.CLASS_NAME,"spoiler-toggle")
        tagspoilclick.click()
        tagspoil = tempdrive.find_elements(By.CSS_SELECTOR,".tag.spoiler")
    except:
        tagspolclick = np.nan
        tagspoil = np.nan
    
    try:
        pcell = tempdrive.find_element(By.CLASS_NAME,"relations").find_elements(By.CLASS_NAME,"media-preview-card")
    except:
        pcell = np.nan
    
    
    format_ = []
    chap_ = []
    tag_Seinen = []
    tag_Shapeshifting = []
    tag_Ships = []
    tag_Shogi = []
    tag_Shoujo = []
    tag_Shounen = []
    tag_Shrine_Maiden = []
    tag_Skateboarding = []
    tag_Skeleton = []
    tag_Slapstick = []
    tag_Slavery = []
    tag_Software_Development = []
    tag_Space = []
    tag_Space_Opera = []
    tag_Spearplay = []
    tag_Steampunk = []
    tag_Stop_Motion = []
    tag_Succubus = []
    tag_Suicide = []
    tag_Sumo = []
    tag_Super_Power = []
    tag_Super_Robot = []
    tag_Superhero = []
    tag_Surfing = []
    tag_Surreal_Comedy = []
    tag_Survival = []
    tag_Swimming = []
    tag_Swordplay = []
    tag_Table_Tennis = []
    tag_Tanks = []
    tag_Tanned_Skin = []
    tag_Teacher = []
    tag_Teens_Love = []
    tag_Tennis = []
    tag_Terrorism = []
    tag_Time_Manipulation = []
    tag_Time_Skip = []
    tag_Tokusatsu = []
    tag_Tomboy = []
    tag_Torture = []
    tag_Tragedy = []
    tag_Trains = []
    tag_Transgender = []
    tag_Travel = []
    tag_Triads = []
    tag_Tsundere = []
    tag_Twins = []
    tag_Urban = []
    tag_Urban_Fantasy = []
    tag_Vampire = []
    tag_Video_Games = []
    tag_Vikings = []
    tag_Villainess = []
    tag_Virtual_World = []
    tag_Volleyball = []
    tag_VTuber = []
    tag_War = []
    tag_Werewolf = []
    tag_Witch = []
    tag_Work = []
    tag_Wrestling = []
    tag_Writing = []
    tag_Wuxia = []
    tag_Yakuza = []
    tag_Yandere = []
    tag_Youkai = []
    tag_Yuri = []
    tag_Zombie = []

    
    
    
    addData(format_,dataset[0])
    addData(chap_,dataset[1])
    addData(vol_,dataset[2])
    addData(status_,dataset[3])
    addData(start_,dataset[4])
    addData(end_,dataset[5])
    addData(avg_score_,dataset[6])
    addData(mean_score_,dataset[7])
    addData(pop_,dataset[8])
    addData(favs_,dataset[9])
    addData(source_,dataset[10])
    addData(genres_,dataset[11])
    addData(name_romaj_,dataset[12])
    addData(name_eng_,dataset[13])
    addData(name_native_,dataset[14])
    addData(name_synon_,dataset[15])
    
    addCTBar(rating_10,ctbar[0])
    addCTBar(rating_20,ctbar[1])
    addCTBar(rating_30,ctbar[2])
    addCTBar(rating_40,ctbar[3])
    addCTBar(rating_50,ctbar[4])
    addCTBar(rating_60,ctbar[5])
    addCTBar(rating_70,ctbar[6])
    addCTBar(rating_80,ctbar[7])
    addCTBar(rating_90,ctbar[8])
    addCTBar(rating_100,ctbar[9])
    
    addText(rated_rank,ranku[0])
    addText(popul_rank,ranku[1])
    
    
    for t in range (len(tagstart)):
        try:
            taglist.append(tagstart[t].find_element(By.TAG_NAME,"a").text)
        except:
            taglist.append(np.nan)
            
    if (tagspoil):        
        for t1 in range (len(tagspoil)):
            try:
                taglist.append(tagspoil[t1].find_element(By.TAG_NAME,"a").text)
            except:
                taglist.append(np.nan)
                
    tags_.append(taglist)
    
    tag_Anti_Hero.append(is_In_List(taglist,'word'))
    
    
    tag_4_koma.append(is_In_List(taglist,'4_koma'))
    tag_Achromatic.append(is_In_List(taglist, 'Achromatic'))
    tag_Achronological_Order.append(is_In_List(taglist,'Achronological Order'))
    tag_Acting.append(is_In_List(taglist,'Acting'))
    tag_Adoption.append(is_In_List(taglist,'Adoption'))
    tag_Advertisement.append(is_In_List(taglist,'Advertisement'))
    tag_Afterlife.append(is_In_List(taglist,'Afterlife'))
    tag_Age_Gap.append(is_In_List(taglist,'Age Gap'))
    tag_Age_Regression.append(is_In_List(taglist,'Age Regression'))
    tag_Agender.append(is_In_List(taglist,'Agender'))
    tag_Agriculture.append(is_In_List(taglist,'Agriculture'))
    tag_Airsoft.append(is_In_List(taglist,'Airsoft'))
    tag_Alchemy.append(is_In_List(taglist,'Alchemy'))
    tag_Aliens.append(is_In_List(taglist,'Aliens'))
    tag_Alternate_Universe.append(is_In_List(taglist,'Alternate Universe'))
    tag_American_Football.append(is_In_List(taglist,'American Football'))
    tag_Amnesia.append(is_In_List(taglist,'Amnesia'))
    tag_Anachronism.append(is_In_List(taglist,'Anachronism'))
    tag_Angels.append(is_In_List(taglist,'Angels'))
    tag_Animals.append(is_In_List(taglist,'Animals'))
    tag_Anthology.append(is_In_List(taglist,'Anthology'))
    tag_Anthropomorphism.append(is_In_List(taglist,'Anthropomorphism'))
    tag_Anti_Hero.append(is_In_List(taglist,'Anti-Hero'))
    tag_Archery.append(is_In_List(taglist,'Archery'))
    tag_Artificial_Intelligence.append(is_In_List(taglist,'Artificial Intelligence'))
    tag_Asexual.append(is_In_List(taglist,'Asexual'))
    tag_Assassins.append(is_In_List(taglist,'Assassins'))
    tag_Astronomy.append(is_In_List(taglist,'Astronomy'))
    tag_Athletics.append(is_In_List(taglist,'Athletics'))
    tag_Augmented_Reality.append(is_In_List(taglist,'Augmented Reality'))
    tag_Autobiographical.append(is_In_List(taglist,'Autobiographical'))
    tag_Aviation.append(is_In_List(taglist,'Aviation'))
    tag_Badminton.append(is_In_List(taglist,'Badminton'))
    tag_Band.append(is_In_List(taglist,'Band'))
    tag_Bar.append(is_In_List(taglist,'Bar'))
    tag_Baseball.append(is_In_List(taglist,'Baseball'))
    tag_Basketball.append(is_In_List(taglist,'Basketball'))
    tag_Battle_Royale.append(is_In_List(taglist,'Battle Royale'))
    tag_Biographical.append(is_In_List(taglist,'Biographical'))
    tag_Bisexual.append(is_In_List(taglist,'Bisexual'))
    tag_Body_Horror.append(is_In_List(taglist,'Body Horror'))
    tag_Body_Swapping.append(is_In_List(taglist,'Body Swapping'))
    tag_Boxing.append(is_In_List(taglist,'Boxing'))
    tag_Boys_Love.append(is_In_List(taglist,"Boys' Love"))
    tag_Bullying.append(is_In_List(taglist,'Bullying'))
    tag_Butler.append(is_In_List(taglist,'Butler'))
    tag_Calligraphy.append(is_In_List(taglist,'Calligraphy'))
    tag_Cannibalism.append(is_In_List(taglist,'Cannibalism'))
    tag_Card_Battle.append(is_In_List(taglist,'Card Battle'))
    tag_Cars.append(is_In_List(taglist,'Cars'))
    tag_Centaur.append(is_In_List(taglist,'Centaur'))
    tag_CGI.append(is_In_List(taglist,'CGI'))
    tag_Cheerleading.append(is_In_List(taglist,'Cheerleading'))
    tag_Chibi.append(is_In_List(taglist,'Chibi'))
    tag_Chimera.append(is_In_List(taglist,'Chimera'))
    tag_Chuunibyou.append(is_In_List(taglist,'Chuunibyou'))
    tag_Circus.append(is_In_List(taglist,'Circus'))
    tag_Classic_Literature.append(is_In_List(taglist,'Classic Literature'))
    tag_Clone.append(is_In_List(taglist,'Clone'))
    tag_College.append(is_In_List(taglist,'College'))
    tag_Coming_of_Age.append(is_In_List(taglist,'Coming of Age'))
    tag_Conspiracy.append(is_In_List(taglist,'Conspiracy'))
    tag_Cosmic_Horror.append(is_In_List(taglist,'Cosmic Horror'))
    tag_Cosplay.append(is_In_List(taglist,'Cosplay'))
    tag_Crime.append(is_In_List(taglist,'Crime'))
    tag_Crossdressing.append(is_In_List(taglist,'Crossdressing'))
    tag_Crossover.append(is_In_List(taglist,'Crossover'))
    tag_Cult.append(is_In_List(taglist,'Cult'))
    tag_Cultivation.append(is_In_List(taglist,'Cultivation'))
    tag_Cute_Boys_Doing_Cute_Things.append(is_In_List(taglist,'Cute Boys Doing Cute Things'))
    tag_Cute_Girls_Doing_Cute_Things.append(is_In_List(taglist,'Cute Girls Doing Cute Things'))
    tag_Cyberpunk.append(is_In_List(taglist,'Cyberpunk'))
    tag_Cyborg.append(is_In_List(taglist,'Cyborg'))
    tag_Cycling.append(is_In_List(taglist,'Cycling'))
    tag_Dancing.append(is_In_List(taglist,'Dancing'))
    tag_Death_Game.append(is_In_List(taglist,'Death Game'))
    tag_Delinquents.append(is_In_List(taglist,'Delinquents'))
    tag_Demons.append(is_In_List(taglist,'Demons'))
    tag_Denpa.append(is_In_List(taglist,'Denpa'))
    tag_Detective.append(is_In_List(taglist,'Detective'))
    tag_Dinosaurs.append(is_In_List(taglist,'Dinosaurs'))
    tag_Disability.append(is_In_List(taglist,'Disability'))
    tag_Dissociative_Identities.append(is_In_List(taglist,'Dissociative Identities'))
    tag_Dragons.append(is_In_List(taglist,'Dragons'))
    tag_Drawing.append(is_In_List(taglist,'Drawing'))
    tag_Drugs.append(is_In_List(taglist,'Drugs'))
    tag_Dullahan.append(is_In_List(taglist,'Dullahan'))
    tag_Dungeon.append(is_In_List(taglist,'Dungeon'))
    tag_Dystopian.append(is_In_List(taglist,'Dystopian'))
    tag_E_Sports.append(is_In_List(taglist,'E-Sports'))
    tag_Economics.append(is_In_List(taglist,'Economics'))
    tag_Educational.append(is_In_List(taglist,'Educational'))
    tag_Elf.append(is_In_List(taglist,'Elf'))
    tag_Ensemble_Cast.append(is_In_List(taglist,'Ensemble Cast'))
    tag_Environmental.append(is_In_List(taglist,'Environmental'))
    tag_Episodic.append(is_In_List(taglist,'Episodic'))
    tag_Ero_Guro.append(is_In_List(taglist,'Ero Guro'))
    tag_Espionage.append(is_In_List(taglist,'Espionage'))
    tag_Fairy_Tale.append(is_In_List(taglist,'Fairy Tale'))
    tag_Family_Life.append(is_In_List(taglist,'Family Life'))
    tag_Fashion.append(is_In_List(taglist,'Fashion'))
    tag_Female_Harem.append(is_In_List(taglist,'Female Harem'))
    tag_Female_Protagonist.append(is_In_List(taglist,'Female Protagonist'))
    tag_Fencing.append(is_In_List(taglist,'Fencing'))
    tag_Firefighters.append(is_In_List(taglist,'Firefighters'))
    tag_Fishing.append(is_In_List(taglist,'Fishing'))
    tag_Fitness.append(is_In_List(taglist,'Fitness'))
    tag_Flash.append(is_In_List(taglist,'Flash'))
    tag_Food.append(is_In_List(taglist,'Food'))
    tag_Football.append(is_In_List(taglist,'Football'))
    tag_Foreign.append(is_In_List(taglist,'Foreign'))
    tag_Found_Family.append(is_In_List(taglist,'Found Family'))
    tag_Fugitive.append(is_In_List(taglist,'Fugitive'))
    tag_Full_CGI.append(is_In_List(taglist,'Full CGI'))
    tag_Full_Color.append(is_In_List(taglist,'Full Color'))
    tag_Gambling.append(is_In_List(taglist,'Gambling'))
    tag_Gangs.append(is_In_List(taglist,'Gangs'))
    tag_Gender_Bending.append(is_In_List(taglist,'Gender Bending'))
    tag_Ghost.append(is_In_List(taglist,'Ghost'))
    tag_Go.append(is_In_List(taglist,'Go'))
    tag_Goblin.append(is_In_List(taglist,'Goblin'))
    tag_Gods.append(is_In_List(taglist,'Gods'))
    tag_Golf.append(is_In_List(taglist,'Golf'))
    tag_Gore.append(is_In_List(taglist,'Gore'))
    tag_Guns.append(is_In_List(taglist,'Guns'))
    tag_Gyaru.append(is_In_List(taglist,'Gyaru'))
    tag_Handball.append(is_In_List(taglist,'Handball'))
    tag_Henshin.append(is_In_List(taglist,'Henshin'))
    tag_Heterosexual.append(is_In_List(taglist,'Heterosexual'))
    tag_Hikikomori.append(is_In_List(taglist,'Hikikomori'))
    tag_Historical.append(is_In_List(taglist,'Historical'))
    tag_Homeless.append(is_In_List(taglist,'Homeless'))
    tag_Ice_Skating.append(is_In_List(taglist,'Ice Skating'))
    tag_Idol.append(is_In_List(taglist,'Idol'))
    tag_Isekai.append(is_In_List(taglist,'Isekai'))
    tag_Iyashikei.append(is_In_List(taglist,'Iyashikei'))
    tag_Josei.append(is_In_List(taglist,'Josei'))
    tag_Judo.append(is_In_List(taglist,'Judo'))
    tag_Kaiju.append(is_In_List(taglist,'Kaiju'))
    tag_Karuta.append(is_In_List(taglist,'Karuta'))
    tag_Kemonomimi.append(is_In_List(taglist,'Kemonomimi'))
    tag_Kids.append(is_In_List(taglist,'Kids'))
    tag_Kuudere.append(is_In_List(taglist,'Kuudere'))
    tag_Lacrosse.append(is_In_List(taglist,'Lacrosse'))
    tag_Language_Barrier.append(is_In_List(taglist,'Language Barrier'))
    tag_LGBTQ_Themes.append(is_In_List(taglist,'LGBTQ+ Themes'))
    tag_Lost_Civilization.append(is_In_List(taglist,'Lost Civilization'))
    tag_Love_Triangle.append(is_In_List(taglist,'Love Triangle'))
    tag_Mafia.append(is_In_List(taglist,'Mafia'))
    tag_Magic.append(is_In_List(taglist,'Magic'))
    tag_Mahjong.append(is_In_List(taglist,'Mahjong'))
    tag_Maids.append(is_In_List(taglist,'Maids'))
    tag_Makeup.append(is_In_List(taglist,'Makeup'))
    tag_Male_Harem.append(is_In_List(taglist,'Male Harem'))
    tag_Male_Protagonist.append(is_In_List(taglist,'Male Protagonist'))
    tag_Martial_Arts.append(is_In_List(taglist,'Martial Arts'))
    tag_Medicine.append(is_In_List(taglist,'Medicine'))
    tag_Memory_Manipulation.append(is_In_List(taglist,'Memory Manipulation'))
    tag_Mermaid.append(is_In_List(taglist,'Mermaid'))
    tag_Meta.append(is_In_List(taglist,'Meta'))
    tag_Military.append(is_In_List(taglist,'Military'))
    tag_Mixed_Gender_Harem.append(is_In_List(taglist,'Mixed Gender Harem'))
    tag_Monster_Boy.append(is_In_List(taglist,'Monster Boy'))
    tag_Monster_Girl.append(is_In_List(taglist,'Monster Girl'))
    tag_Mopeds.append(is_In_List(taglist,'Mopeds'))
    tag_Motorcycles.append(is_In_List(taglist,'Motorcycles'))
    tag_Musical.append(is_In_List(taglist,'Musical'))
    tag_Mythology.append(is_In_List(taglist,'Mythology'))
    tag_Necromancy.append(is_In_List(taglist,'Necromancy'))
    tag_Nekomimi.append(is_In_List(taglist,'Nekomimi'))
    tag_Ninja.append(is_In_List(taglist,'Ninja'))
    tag_No_Dialogue.append(is_In_List(taglist,'No Dialogue'))
    tag_Noir.append(is_In_List(taglist,'Noir'))
    tag_Non_fiction.append(is_In_List(taglist,'Non-fiction'))
    tag_Nudity.append(is_In_List(taglist,'Nudity'))
    tag_Nun.append(is_In_List(taglist,'Nun'))
    tag_Office_Lady.append(is_In_List(taglist,'Office Lady'))
    tag_Oiran.append(is_In_List(taglist,'Oiran'))
    tag_Ojou_sama.append(is_In_List(taglist,'Ojou-sama'))
    tag_Orphan.append(is_In_List(taglist,'Orphan'))
    tag_Otaku_Culture.append(is_In_List(taglist,'Otaku Culture'))
    tag_Outdoor.append(is_In_List(taglist,'Outdoor'))
    tag_Pandemic.append(is_In_List(taglist,'Pandemic'))
    tag_Parkour.append(is_In_List(taglist,'Parkour'))
    tag_Parody.append(is_In_List(taglist,'Parody'))
    tag_Philosophy.append(is_In_List(taglist,'Philosophy'))
    tag_Photography.append(is_In_List(taglist,'Photography'))
    tag_Pirates.append(is_In_List(taglist,'Pirates'))
    tag_Poker.append(is_In_List(taglist,'Poker'))
    tag_Police.append(is_In_List(taglist,'Police'))
    tag_Politics.append(is_In_List(taglist,'Politics'))
    tag_Post_Apocalyptic.append(is_In_List(taglist,'Post-Apocalyptic'))
    tag_POV.append(is_In_List(taglist,'POV'))
    tag_Primarily_Adult_Cast.append(is_In_List(taglist,'Primarily Adult Cast'))
    tag_Primarily_Child_Cast.append(is_In_List(taglist,'Primarily Child Cast'))
    tag_Primarily_Female_Cast.append(is_In_List(taglist,'Primarily Female Cast'))
    tag_Primarily_Male_Cast.append(is_In_List(taglist,'Primarily Male Cast'))
    tag_Primarily_Teen_Cast.append(is_In_List(taglist,'Primarily Teen Cast'))
    tag_Puppetry.append(is_In_List(taglist,'Puppetry'))
    tag_Rakugo.append(is_In_List(taglist,'Rakugo'))
    tag_Real_Robot.append(is_In_List(taglist,'Real Robot'))
    tag_Rehabilitation.append(is_In_List(taglist,'Rehabilitation'))
    tag_Reincarnation.append(is_In_List(taglist,'Reincarnation'))
    tag_Religion.append(is_In_List(taglist,'Religion'))
    tag_Revenge.append(is_In_List(taglist,'Revenge'))
    tag_Robots.append(is_In_List(taglist,'Robots'))
    tag_Rotoscoping.append(is_In_List(taglist,'Rotoscoping'))
    tag_Rugby.append(is_In_List(taglist,'Rugby'))
    tag_Rural.append(is_In_List(taglist,'Rural'))
    tag_Samurai.append(is_In_List(taglist,'Samurai'))
    tag_Satire.append(is_In_List(taglist,'Satire'))
    tag_School.append(is_In_List(taglist,'School'))
    tag_School_Club.append(is_In_List(taglist,'School Club'))
    tag_Scuba_Diving.append(is_In_List(taglist,'Scuba Diving'))
    tag_Seinen.append(is_In_List(taglist,'Seinen'))
    tag_Shapeshifting.append(is_In_List(taglist,'Shapeshifting'))
    tag_Ships.append(is_In_List(taglist,'Ships'))
    tag_Shogi.append(is_In_List(taglist,'Shogi'))
    tag_Shoujo.append(is_In_List(taglist,'Shoujo'))
    tag_Shounen.append(is_In_List(taglist,'Shounen'))
    tag_Shrine_Maiden.append(is_In_List(taglist,'Shrine Maiden'))
    tag_Skateboarding.append(is_In_List(taglist,'Skateboarding'))
    tag_Skeleton.append(is_In_List(taglist,'Skeleton'))
    tag_Slapstick.append(is_In_List(taglist,'Slapstick'))
    tag_Slavery.append(is_In_List(taglist,'Slavery'))
    tag_Software_Development.append(is_In_List(taglist,'Software Development'))
    tag_Space.append(is_In_List(taglist,'Space'))
    tag_Space_Opera.append(is_In_List(taglist,'Space Opera'))
    tag_Spearplay.append(is_In_List(taglist,'Spearplay'))
    tag_Steampunk.append(is_In_List(taglist,'Steampunk'))
    tag_Stop_Motion.append(is_In_List(taglist,'Stop Motion'))
    tag_Succubus.append(is_In_List(taglist,'Succubus'))
    tag_Suicide.append(is_In_List(taglist,'Suicide'))
    tag_Sumo.append(is_In_List(taglist,'Sumo'))
    tag_Super_Power.append(is_In_List(taglist,'Super Power'))
    tag_Super_Robot.append(is_In_List(taglist,'Super Robot'))
    tag_Superhero.append(is_In_List(taglist,'Superhero'))
    tag_Surfing.append(is_In_List(taglist,'Surfing'))
    tag_Surreal_Comedy.append(is_In_List(taglist,'Surreal Comedy'))
    tag_Survival.append(is_In_List(taglist,'Survival'))
    tag_Swimming.append(is_In_List(taglist,'Swimming'))
    tag_Swordplay.append(is_In_List(taglist,'Swordplay'))
    tag_Table_Tennis.append(is_In_List(taglist,'Table Tennis'))
    tag_Tanks.append(is_In_List(taglist,'Tanks'))
    tag_Tanned_Skin.append(is_In_List(taglist,'Tanned Skin'))
    tag_Teacher.append(is_In_List(taglist,'Teacher'))
    tag_Teens_Love.append(is_In_List(taglist,"Teens' Love"))
    tag_Tennis.append(is_In_List(taglist,'Tennis'))
    tag_Terrorism.append(is_In_List(taglist,'Terrorism'))
    tag_Time_Manipulation.append(is_In_List(taglist,'Time Manipulation'))
    tag_Time_Skip.append(is_In_List(taglist,'Time Skip'))
    tag_Tokusatsu.append(is_In_List(taglist,'Tokusatsu'))
    tag_Tomboy.append(is_In_List(taglist,'Tomboy'))
    tag_Torture.append(is_In_List(taglist,'Torture'))
    tag_Tragedy.append(is_In_List(taglist,'Tragedy'))
    tag_Trains.append(is_In_List(taglist,'Trains'))
    tag_Transgender.append(is_In_List(taglist,'Transgender'))
    tag_Travel.append(is_In_List(taglist,'Travel'))
    tag_Triads.append(is_In_List(taglist,'Triads'))
    tag_Tsundere.append(is_In_List(taglist,'Tsundere'))
    tag_Twins.append(is_In_List(taglist,'Twins'))
    tag_Urban.append(is_In_List(taglist,'Urban'))
    tag_Urban_Fantasy.append(is_In_List(taglist,'Urban Fantasy'))
    tag_Vampire.append(is_In_List(taglist,'Vampire'))
    tag_Video_Games.append(is_In_List(taglist,'Video Games'))
    tag_Vikings.append(is_In_List(taglist,'Vikings'))
    tag_Villainess.append(is_In_List(taglist,'Villainess'))
    tag_Virtual_World.append(is_In_List(taglist,'Virtual World'))
    tag_Volleyball.append(is_In_List(taglist,'Volleyball'))
    tag_VTuber.append(is_In_List(taglist,'VTuber'))
    tag_War.append(is_In_List(taglist,'War'))
    tag_Werewolf.append(is_In_List(taglist,'Werewolf'))
    tag_Witch.append(is_In_List(taglist,'Witch'))
    tag_Work.append(is_In_List(taglist,'Work'))
    tag_Wrestling.append(is_In_List(taglist,'Wrestling'))
    tag_Writing.append(is_In_List(taglist,'Writing'))
    tag_Wuxia.append(is_In_List(taglist,'Wuxia'))
    tag_Yakuza.append(is_In_List(taglist,'Yakuza'))
    tag_Yandere.append(is_In_List(taglist,'Yandere'))
    tag_Youkai.append(is_In_List(taglist,'Youkai'))
    tag_Yuri.append(is_In_List(taglist,'Yuri'))
    tag_Zombie.append(is_In_List(taglist,'Zombie'))
    
    
    try:
        cell1_role.append(pcell[0].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info-header").text)
    except:
        cell1_role.append(np.nan)
    try:
        cell1_type.append(pcell[0].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info").text)
    except:
        cell1_type.append(np.nan)
    try:
        cell2_role.append(pcell[1].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info-header").text)
    except:
        cell2_role.append(np.nan) 
    try:
        cell2_type.append(pcell[1].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info").text)
    except:
        cell2_type.append(np.nan)
        
        
    data = {"Name Romaji":name_romaj_,
            "Name Native":name_native_,
            "Name English":name_eng_,
            "Synonyms":name_synon_,
            "Format":format_,
            "Chapter Count":chap_,
            "Volume Count":vol_,
            "Status":status_,
            "Start Date":start_,
            "End Date":end_,
            "Average Score":avg_score_,
            "Mean Score":mean_score_,
            "Popularity":pop_,
            "Favorites":favs_,
            "Source":source_,
            "Genres":genres_,
            "Rating 10":rating_10,
            "Rating 20":rating_20,
            "Rating 30":rating_30,
            "Rating 40":rating_40,
            "Rating 50":rating_50,
            "Rating 60":rating_60,
            "Rating 70":rating_70,
            "Rating 80":rating_80,
            "Rating 90":rating_90,
            "Rating 100":rating_100,
            "Rating Rank":rated_rank,
Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e  ようこそ実力至上主義の教室へ
#
#              Name English                                           Synonyms  \
# 0  Classroom of the Elite  Youjitsu\nYou-Zitsu\nขอต้อนรับสู่ห้องเรียนนิยม...
#
#         Format Chapter Count Volume Count    Status    Start Date  \
# 0  Light Novel           110           14  Finished  May 25, 2015
#
#        End Date  ... Rating 90 Rating 100                Rating Rank  \
# 0  Sep 25, 2019  ...      1974       2916  #2 Highest Rated All Time
#
#             Popularity Rank  \
# 0  #1 Most Popular All Time
#
#                                            User Tags   Related 1  \
# 0  [School, Male Protagonist, Philosophy, Seinen,...  Adaptation
#
#   Related 1 Type   Related 2     Related 2 Type Tag_Anti-Hero
# 0  TV · Finished  Adaptation  Manga · Releasing             1
#
# [1 rows x 34 columns]

# %%
    tempdrive = webdriver.Chrome()
    tempdrive.get("https://anilist.co/manga/94970/Youkoso-Jitsuryoku-Shijou-Shugi-no-Kyoushitsu-e/")
    time.sleep(1)
    
    try:
        tagspoilclick = tempdrive.find_element(By.CLASS_NAME,"spoiler-toggle")
        tagspoilclick.click()
        tagspoil = tempdrive.find_elements(By.CSS_SELECTOR,".tag.spoiler")
    except:
        tagspolclick = np.nan
        tagspoil = np.nan
        
    tagstart = tempdrive.find_elements(By.CLASS_NAME,"tag")
    
    tags_ = []
    taglist = []
    tag_Anti_Hero = []
    
    for t in range (len(tagstart)):
        try:
            taglist.append(tagstart[t].find_element(By.TAG_NAME,"a").text)
        except:
            taglist.append(np.nan)
            
    if (tagspoil):        
        for t1 in range (len(tagspoil)):
            try:
                taglist.append(tagspoil[t1].find_element(By.TAG_NAME,"a").text)
            except:
                taglist.append(np.nan)
                
                
    print(taglist)
                
    tag_Anti_Hero.append(is_In_List(taglist,'Anti-Hero'))
        
            
    tags_.append(taglist)
    
    
    print(tag_Anti_Hero)
    
    tempdrive.quit()
# Out:
# ['School', 'Male Protagonist', 'Anti-Hero', 'Philosophy', 'Battle Royale', 'Seinen', 'Primarily Teen Cast', 'Heterosexual', 'Ensemble Cast', 'Survival', 'Conspiracy', 'Revenge', 'Coming of Age', 'Fugitive', 'Tsundere', 'Torture', 'Bullying', 'Kuudere', 'Politics', 'Denpa', 'Delinquents', 'Yandere', 'Classic Literature', 'Athletics', 'Love Triangle', 'Female Harem', 'Martial Arts', 'Suicide', 'Teacher', 'LGBTQ+ Themes', 'Anti-Hero', 'Battle Royale', 'Survival', 'Conspiracy', 'Revenge', 'Fugitive', 'Torture', 'Bullying', 'Politics', 'Denpa', 'Yandere', 'Love Triangle', 'Martial Arts', 'Suicide']
# [1]

# %%
Action
Adventure
Comedy
Drama
Ecchi
Fantasy
Horror
Mahou Shoujo
Mecha
Music
Mystery
Psychological
Romance
Sci-Fi
Slice of Life
Sports
Supernatural
Thriller






4-koma
Achromatic
Achronological Order
Acting
Adoption
Advertisement
Afterlife
Age Gap
Age Regression
Agender
Agriculture
Airsoft
