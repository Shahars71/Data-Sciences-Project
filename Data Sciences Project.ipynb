# %% [markdown]
# # Data Sciences Project

# %%
#!pip install selenium


import bs4
from bs4 import BeautifulSoup

import pandas as pd
import scipy as sc
import numpy as np
import math


import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

import time

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns



import sklearn
from sklearn import linear_model, metrics, preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import r2_score, f1_score

# %% [markdown]
# ## Functions

# %%
def addData(arr,data):
    try:
        arr.append(data.find_element(By.CLASS_NAME,"value").text)
    except:
        arr.append(np.nan)

# %%
def addCTBar(arr,data):
    try:
        arr.append(data.get_attribute("ct:value"))
    except:
        arr.append(np.nan)

# %%
def addText(arr,data):
    try:
        arr.append(data.text)
    except:
        arr.append(np.nan)

# %%
def is_In_List(arr,word):
    for t in range(len(arr)):
        if (arr[t] == word):
            #print(word)
            return 1
    return 0

# %% [markdown]
# ## Crawling

# %%
PATH = "\chromedriver.exe"
driver = webdriver.Chrome()

driver.get("https://anilist.co/search/manga?format=NOVEL")

time.sleep(2)

# %%
for j in range(2000):
    driver.execute_script("window.scrollTo(0," + str(j * 1000) + ");")
    time.sleep(2)
    
links = driver.find_elements(By.CLASS_NAME,"media-card")
link_list = [elem.find_element(By.CLASS_NAME,"cover").get_attribute('href') for elem in links]

driver.quit()

# %%
def get_data_into_df(link):
    tempdrive = webdriver.Chrome()
    tempdrive.get(link)
    time.sleep(1)
    
    
    #init dataset element list
    try:
        dataset = tempdrive.find_elements(By.CLASS_NAME,"data-set")
    except:
        dataset = []
    
    
    #init ctbar element list
    try:
        ctbar = tempdrive.find_element(By.CLASS_NAME,"grid-section-wrap").find_elements(By.TAG_NAME,"g")[2].find_elements(By.CLASS_NAME,"ct-bar")#.get_attribute("ct:value")
    except:
        ctbar = []
        
    try:
        ctlabels = tempdrive.find_element(By.CLASS_NAME,"grid-section-wrap").find_element(By.CLASS_NAME,"ct-labels").find_elements(By.XPATH,"//span[contains(@class,'ct-label ct-horizontal ct-end')]")
    except:
        ctlabels = []
    
    #init rankings element list
    try:
        ranku = tempdrive.find_element(By.CLASS_NAME,"rankings").find_elements(By.CLASS_NAME,"rank-text")
    except:
        ranku = []
    
    
    #init tags element list
    try:
        tagspoilclick = tempdrive.find_element(By.CLASS_NAME,"spoiler-toggle")
        tagspoilclick.click()
        taglist = tempdrive.find_elements(By.CSS_SELECTOR,".el-tooltip.name")
    except:
        tagspolclick = []
        taglist = []
    
    
    #init relations element list
    try:
        pcell = tempdrive.find_element(By.CLASS_NAME,"relations").find_elements(By.CLASS_NAME,"media-preview-card")
    except:
        pcell = []
        
        
        
    #help with skipped ctbar nums
    ctbarcount = 0
    
    #check if english name exists
    engFlag = True
    
    
    #dataset element features
    format_ = []
    chap_ = []
    vol_ = []
    status_ = []
    start_ = []
    end_ = []
    avg_score_ = []
    mean_score_ = []
    pop_ = []
    favs_ = []
    source_ = []
    genres_ = []
    name_romaj_ = []
    name_eng_ = []
    name_native_ = []
    name_synon_ = []
    
    #dataset feature flags
    format_Flag = False
    chap_Flag = False
    vol_Flag = False
    status_Flag = False
    start_Flag = False
    end_Flag = False
    avg_score_Flag = False
    mean_score_Flag = False
    pop_Flag = False
    favs_Flag = False
    source_Flag = False
    genres_Flag = False
    name_romaj_Flag = False
    name_eng_Flag = False
    name_native_Flag = False
    name_synon_Flag = False
    
    
    #ctbar element features
    rating_10 = []
    rating_20 = []
    rating_30 = []
    rating_40 = []
    rating_50 = []
    rating_60 = []
    rating_70 = []
    rating_80 = []
    rating_90 = []
    rating_100 = []
    
    #ctbar element flags
    rating_10_Flag = False
    rating_20_Flag = False
    rating_30_Flag = False
    rating_40_Flag = False
    rating_50_Flag = False
    rating_60_Flag = False
    rating_70_Flag = False
    rating_80_Flag = False
    rating_90_Flag = False
    rating_100_Flag = False
    
    #rankings element features
    rated_rank = []
    popul_rank = []
    
    #relations element features
    cell1_role = []
    cell1_type = []
    cell2_role = []
    cell2_type = []

    #Genres
    gen_one = []
    gen_two = []
    gen_thr = []
    
    #Tags
    tag_one = []
    tag_two = []
    tag_thr = []
    
    #Weird feature but let's try
    name_word_count = []
    
    #Gotta save links
    links_ = []

    
    
    #Check and Handle appending of dataset features
    
    for p in dataset:
        
        testStr = p.find_element(By.CLASS_NAME,"type").text
        
        if ((testStr == "Format") & (format_Flag == False)):
            format_Flag = True
            try:
                addData(format_,p)
            except:
                format_.append(np.nan)
        
        if ((testStr == "Chapters") & (chap_Flag == False)):
            chap_Flag = True
            try:
                addData(chap_,p)
            except:
                chap_.append(np.nan)
        
        if ((testStr == "Volumes") & (vol_Flag == False)):
            vol_Flag = True
            try:
                addData(vol_,p)
            except:
                vol_.append(np.nan)
            
        if ((testStr == "Status") & (status_Flag == False)):
            status_Flag = True
            try:
                addData(status_,p)
            except:
                status_.append(np.nan)
        
        if ((testStr == "Start Date") & (start_Flag == False)):
            start_Flag = True
            try:
                addData(start_,p)
            except:
                start_.append(np.nan)
        
        if ((testStr == "End Date") & (end_Flag == False)):
            end_Flag = True
            try:
                addData(end_,p)
            except:
                end_.append(np.nan)
            
        if ((testStr == "Average Score") & (avg_score_Flag == False)):
            avg_score_Flag = True
            try:
                addData(avg_score_,p)
            except:
                avg_score_.append(np.nan)
            
        if ((testStr == "Mean Score") & (mean_score_Flag == False)):
            mean_score_Flag = True
            try:
                addData(mean_score_,p)
            except:
                mean_score_.append(np.nan)
                
        if ((testStr == "Popularity") & (pop_Flag == False)):
            pop_Flag = True
            try:    
                addData(pop_,p)
            except:
                pop_.append(np.nan)
            
        if ((testStr == "Favorites") & (favs_Flag == False)):
            favs_Flag = True
            try:
                addData(favs_,p)
            except:
                favs_.append(np.nan)
            
        if ((testStr == "Source") & (source_Flag == False)):
            source_Flag = True
            try:
                addData(source_,p)
            except:
                source_.append(np.nan)
            
        if ((testStr == "Genres") & (genres_Flag == False)):
            genres_Flag = True
            try:
                addData(genres_,p)
            except:
                genres_.append(np.nan)
            
        if ((testStr == "Romaji") & (name_romaj_Flag == False)):
            name_romaj_Flag = True
            try:
                addData(name_romaj_,p)
            except:
                name_romaj_.append(np.nan)
        
        if ((testStr == "English") & (name_eng_Flag == False)):
            name_eng_Flag = True
            try:
                if (p.find_element(By.CLASS_NAME,"type").text == "English"):
                    addData(name_eng_,p)
                else:
                    engFlag = False
                    #print(engFlag)
                    name_eng.append(np.nan)
            except:
                name_eng_.append(np.nan)
            
        if ((testStr == "Native") & (name_native_Flag == False)):
            name_native_Flag = True
            try:
                if (engFlag):
                    addData(name_native_,p)
                else:
                    addData(name_native_,p)
            except:
                name_native_.append(np.nan)
            
        if ((testStr == "Synonyms") & (name_synon_Flag == False)):
            name_synon_Flag = True
            try:
                if (engFlag):
                    addData(name_synon_,p)
                else:
                    addData(name_synon_,p)
            except:
                name_synon_.append(np.nan)
                
                
    #If any feature was missing from an entry, append NaN  
    if (format_Flag == False):  
        format_.append(np.nan)
        
    if (chap_Flag == False):  
        chap_.append(np.nan)
        
    if (vol_Flag == False):  
        vol_.append(np.nan)

    if (status_Flag == False):  
        status_.append(np.nan)
    
    if (start_Flag == False):  
        start_.append(np.nan)
    
    if (end_Flag == False):  
        end_.append(np.nan)
    
    if (avg_score_Flag == False):  
        avg_score_.append(np.nan)
    
    if (mean_score_Flag == False):  
        mean_score_.append(np.nan)
    
    if (pop_Flag == False):  
        pop_.append(np.nan)
    
    if (favs_Flag == False):  
        favs_.append(np.nan)
    
    if (source_Flag == False):  
        source_.append(np.nan)
    
    if (genres_Flag == False):  
        genres_.append(np.nan)
    
    if (name_romaj_Flag == False):  
        name_romaj_.append(np.nan)
    
    if (name_eng_Flag == False):  
        name_eng_.append(np.nan)
    
    if (name_native_Flag == False):  
        name_native_.append(np.nan)

    if (name_synon_Flag == False):  
        name_synon_.append(np.nan)
    

    
    #Handle appending of ctbar features
    for t in range(len(ctbar)):
        
        ctstr = ctlabels[t].get_attribute('innerHTML')
        
        if ((ctstr == '10') & (rating_10_Flag == False)):
            rating_10_Flag = True
            try:
                addCTBar(rating_10,ctbar[t])
            except:
                rating_10.append(np.nan)
                
        if ((ctstr == '20') & (rating_20_Flag == False)):
            rating_20_Flag = True
            try:
                addCTBar(rating_20,ctbar[t])
            except:
                rating_20.append(np.nan)
                
        if ((ctstr == '30') & (rating_30_Flag == False)):
            rating_30_Flag = True
            try:
                addCTBar(rating_30,ctbar[t])
            except:
                rating_30.append(np.nan)
                
        if ((ctstr == '40') & (rating_40_Flag == False)):
            rating_40_Flag = True
            try:
                addCTBar(rating_40,ctbar[t])
            except:
                rating_40.append(np.nan)
                
        if ((ctstr == '50') & (rating_50_Flag == False)):
            rating_50_Flag = True
            try:
                addCTBar(rating_50,ctbar[t])
            except:
                rating_50.append(np.nan)
                
        if ((ctstr == '60') & (rating_60_Flag == False)):
            rating_60_Flag = True
            try:
                addCTBar(rating_60,ctbar[t])
            except:
                rating_60.append(np.nan)  
                
        if ((ctstr == '70') & (rating_70_Flag == False)):
            rating_70_Flag = True
            try:
                addCTBar(rating_70,ctbar[t])
            except:
                rating_70.append(np.nan)
                
        if ((ctstr == '80') & (rating_80_Flag == False)):
            rating_80_Flag = True
            try:
                addCTBar(rating_80,ctbar[t])
            except:
                rating_80.append(np.nan)
              
        if ((ctstr == '90') & (rating_90_Flag == False)):
            rating_90_Flag = True
            try:
                addCTBar(rating_90,ctbar[t])
            except:
                rating_90.append(np.nan)
              
        if ((ctstr == '100') & (rating_100_Flag == False)):
            rating_100_Flag = True
            try:
                addCTBar(rating_100,ctbar[t])
            except:
                rating_100.append(np.nan)    

                    
                    
                    
    if (rating_10_Flag == False):
        rating_10.append(np.nan)
   
    if (rating_20_Flag == False):
        rating_20.append(np.nan)
    
    if (rating_30_Flag == False):
        rating_30.append(np.nan)
    
    if (rating_40_Flag == False):
        rating_40.append(np.nan)
    
    if (rating_50_Flag == False):
        rating_50.append(np.nan)
    
    if (rating_60_Flag == False):
        rating_60.append(np.nan)
    
    if (rating_70_Flag == False):
        rating_70.append(np.nan)
    
    if (rating_80_Flag == False):
        rating_80.append(np.nan)
    
    if (rating_90_Flag == False):
        rating_90.append(np.nan)
    
    if (rating_100_Flag == False):
        rating_100.append(np.nan)


    
    #Handle appending of rankings features
    try:
        addText(rated_rank,ranku[0])
    except:
        rated_rank.append(np.nan)
        
    try:
        addText(popul_rank,ranku[1])
    except:
        popul_rank.append(np.nan)
        
    
    #Handle appending of top 3 tags features
    
    try:
        tag_one.append(taglist[0].text)
    except:
        tag_one.append(np.nan)
        
    try:
        tag_two.append(taglist[1].text)
    except:
        tag_two.append(np.nan)
        
    try:
        tag_thr.append(taglist[2].text)
    except:
        tag_thr.append(np.nan)
        
    #Handle appending of top 3 genres features
    
    try:
        genArr = genres_[0].split('\n')
    except:
        genArr = []
        
    try:
        gen_one.append(genArr[0])
    except:
        gen_one.append(np.nan)
    
    try:    
        gen_two.append(genArr[1])
    except:
        gen_two.append(np.nan)
    
    try:    
        gen_thr.append(genArr[2])
    except:
        gen_thr.append(np.nan)
    
    try:
        name_word_count.append(len(name_romaj_[0].split(' ')))
    except:
        name_word_count.append(np.nan)
    
    #Handle appending of relations features
    try:
        cell1_role.append(pcell[0].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info-header").text)
    except:
        cell1_role.append(np.nan)
    try:
        cell1_type.append(pcell[0].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info").text)
    except:
        cell1_type.append(np.nan)
    try:
        cell2_role.append(pcell[1].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info-header").text)
    except:
        cell2_role.append(np.nan) 
    try:
        cell2_type.append(pcell[1].find_element(By.CLASS_NAME,"content").find_element(By.CLASS_NAME,"info").text)
    except:
        cell2_type.append(np.nan)
    
    
    links_.append(link)
        
    data = {"Name Romaji":name_romaj_,
            "Name Native":name_native_,
            "Name English":name_eng_,
            "Synonyms":name_synon_,
            "Format":format_,
            "Chapter Count":chap_,
            "Volume Count":vol_,
            "Status":status_,
            "Start Date":start_,
            "End Date":end_,
            "Average Score":avg_score_,
            "Mean Score":mean_score_,
            "Popularity":pop_,
            "Favorites":favs_,
            "Source":source_,
            
            "Genre_One":gen_one,
            "Genre_Two":gen_two,
            "Genre_Three":gen_thr,
            
            "Tag_One":tag_one,
            "Tag_Two":tag_two,
            "Tag_Three":tag_thr,
            
            "Rating 10":rating_10,
            "Rating 20":rating_20,
            "Rating 30":rating_30,
            "Rating 40":rating_40,
            "Rating 50":rating_50,
            "Rating 60":rating_60,
            "Rating 70":rating_70,
            "Rating 80":rating_80,
            "Rating 90":rating_90,
            "Rating 100":rating_100,
            
            "Rating Rank":rated_rank,
            "Popularity Rank":popul_rank,
            
            "Related 1":cell1_role,
            "Related 1 Type":cell1_type,
            "Related 2":cell2_role,
            "Related 2 Type":cell2_type,
            
            "Name Word Count":name_word_count,
            "Link":links_,
            }
    #tempdrive.quit()
    df = pd.DataFrame(data)
    df
    return df

# %%
raw_data = get_data_into_df(link_list[0])

print(len(link_list))

for k in range(1,len(link_list)):
    temp_df = get_data_into_df(link_list[k])
    raw_data = pd.concat([raw_data,temp_df])
    print(k," / ",len(link_list))
    
    if (k % 50 == 0): time.sleep(5)

raw_data
# Out:
# 6860
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_73596\2716971708.py in <module>
#       4
#       5 for k in range(1,len(link_list)):
# ----> 6     temp_df = get_data_into_df(link_list[k])
#       7     raw_data = pd.concat([raw_data,temp_df])
#       8
#
# ~\AppData\Local\Temp\ipykernel_73596\3575207904.py in get_data_into_df(link)
#       1 def get_data_into_df(link):
#       2     tempdrive = webdriver.Chrome()
# ----> 3     tempdrive.get(link)
#       4     time.sleep(1)
#       5
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     453         Loads a web page in the current browser session.
#     454         """
# --> 455         self.execute(Command.GET, {"url": url})
#     456
#     457     @property
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     440                 params["sessionId"] = self.session_id
#     441
# --> 442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
#     444             self.error_handler.check_response(response)
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     292         data = utils.dump_json(params)
#     293         url = f"{self._url}{path}"
# --> 294         return self._request(command_info[0], url, body=data)
#     295
#     296     def _request(self, method, url, body=None):
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     314
#     315         if self.keep_alive:
# --> 316             response = self._conn.request(method, url, body=body, headers=headers)
#     317             statuscode = response.status
#     318         else:
#
# F:\Anaconda\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# F:\Anaconda\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# F:\Anaconda\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# F:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# F:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# F:\Anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# F:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# F:\Anaconda\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# F:\Anaconda\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# F:\Anaconda\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# F:\Anaconda\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
raw_data.to_csv('raw_data.csv')
raw_data.to_excel('raw_data_exc.xlsx')

# %%
dat = pd.read_csv("raw_data.csv")
dat
# Out:
#       Unnamed: 0                                      Name Romaji  \
# 0              0  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e
# 1              0                              Mikkakan no Koufuku
# 2              0         Mushoku Tensei: Isekai Ittara Honki Dasu
# 3              0                  Utsuro no Hako to Zero no Maria
# 4              0            Re:Zero kara Hajimeru Isekai Seikatsu
# ...          ...                                              ...
# 4690           0                                              NaN
# 4691           0                                              NaN
# 4692           0                                              NaN
# 4693           0                                              NaN
# 4694           0                           Youheidan no Ryouriban
#
#              Name Native                              Name English  \
# 0         ようこそ実力至上主義の教室へ                    Classroom of the Elite
# 1                 三日間の幸福                   Three Days of Happiness
# 2     無職転生 ～異世界行ったら本気だす～     Mushoku Tensei: Jobless Reincarnation
# 3             空ろの箱と零のマリア            The Empty Box and Zeroth Maria
# 4        Re:ゼロから始める異世界生活  Re:ZERO -Starting Life in Another World-
# ...                  ...                                       ...
# 4690                 NaN                                       NaN
# 4691                 NaN                                       NaN
# 4692                 NaN                                       NaN
# 4693                 NaN                                       NaN
# 4694             傭兵団の料理番                                       NaN
#
#                                                Synonyms       Format  \
# 0     Youjitsu\nYou-Zitsu\nขอต้อนรับสู่ห้องเรียนนิยม...  Light Novel
# 1     Ba ngày hạnh phúc\n三日間的幸福\nIch habe mein Leben...  Light Novel
# 2                                 เกิดชาตินี้พี่ต้องเทพ  Light Novel
# 3     Hakomari\nZerowa Maria i puste pudełko\nПустая...  Light Novel
# 4     ReZero\nRe: Life in a different world from zer...  Light Novel
# ...                                                 ...          ...
# 4690                                                NaN          NaN
# 4691                                                NaN          NaN
# 4692                                                NaN          NaN
# 4693                                                NaN          NaN
# 4694                     ยอดกุ๊กสูตรเด็ดเสร็จทั้งกองทัพ  Light Novel
#
#       Chapter Count  Volume Count     Status    Start Date  ... Rating 80  \
# 0               NaN          14.0   Finished  May 25, 2015  ...     969.0
# 1               NaN           1.0   Finished           NaN  ...     512.0
# 2               NaN          26.0   Finished  Jan 23, 2014  ...     786.0
# 3               NaN           7.0   Finished   Jan 7, 2009  ...     535.0
# 4               NaN           NaN  Releasing  Jan 24, 2014  ...     556.0
# ...             ...           ...        ...           ...  ...       ...
# 4690            NaN           NaN        NaN           NaN  ...       NaN
# 4691            NaN           NaN        NaN           NaN  ...       NaN
# 4692            NaN           NaN        NaN           NaN  ...       NaN
# 4693            NaN           NaN        NaN           NaN  ...       NaN
# 4694            NaN           NaN  Releasing  Oct 31, 2016  ...       NaN
#
#      Rating 90 Rating 100                 Rating Rank  \
# 0       1976.0     2921.0   #3 Highest Rated All Time
# 1       1319.0     1752.0   #1 Highest Rated All Time
# 2       1558.0     2452.0   #6 Highest Rated All Time
# 3        944.0     1497.0  #15 Highest Rated All Time
# 4       1004.0     1614.0  #12 Highest Rated All Time
# ...        ...        ...                         ...
# 4690       NaN        NaN                         NaN
# 4691       NaN        NaN                         NaN
# 4692       NaN        NaN                         NaN
# 4693       NaN        NaN                         NaN
# 4694       NaN        NaN                         NaN
#
#                Popularity Rank   Related 1     Related 1 Type   Related 2  \
# 0     #1 Most Popular All Time  Adaptation      TV · Finished  Adaptation
# 1     #2 Most Popular All Time  Adaptation   Manga · Finished         NaN
# 2     #3 Most Popular All Time  Adaptation  Manga · Releasing  Adaptation
# 3     #4 Most Popular All Time         NaN                NaN         NaN
# 4     #5 Most Popular All Time  Adaptation   Manga · Finished  Adaptation
# ...                        ...         ...                ...         ...
# 4690                       NaN         NaN                NaN         NaN
# 4691                       NaN         NaN                NaN         NaN
# 4692                       NaN         NaN                NaN         NaN
# 4693                       NaN         NaN                NaN         NaN
# 4694                       NaN         NaN                NaN         NaN
#
#          Related 2 Type Name Word Count
# 0     Manga · Releasing             7.0
# 1                   NaN             3.0
# 2         TV · Finished             6.0
# 3                   NaN             7.0
# 4      Manga · Finished             5.0
# ...                 ...             ...
# 4690                NaN             NaN
# 4691                NaN             NaN
# 4692                NaN             NaN
# 4693                NaN             NaN
# 4694                NaN             3.0
#
# [4695 rows x 39 columns]

# %%
dat_clean = dat.copy()
dat_clean.dropna(inplace = True, how='all')
dat_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 0 to 4694
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name Romaji      2436 non-null   object
#  1   Name Native      2430 non-null   object
#  2   Name English     499 non-null    object
#  3   Synonyms         1481 non-null   object
#  4   Format           2436 non-null   object
#  5   Chapter Count    0 non-null      float64
#  6   Volume Count     1512 non-null   float64
#  7   Status           2436 non-null   object
#  8   Start Date       1783 non-null   object
#  9   End Date         808 non-null    object
#  10  Average Score    532 non-null    object
#  11  Mean Score       1798 non-null   object
#  12  Popularity       2436 non-null   float64
#  13  Favorites        1623 non-null   float64
#  14  Source           2222 non-null   object
#  15  Genre_One        2407 non-null   object
#  16  Genre_Two        2107 non-null   object
#  17  Genre_Three      1410 non-null   object
#  18  Tag_One          217 non-null    object
#  19  Tag_Two          215 non-null    object
#  20  Tag_Three        212 non-null    object
#  21  Rating 10        1074 non-null   float64
#  22  Rating 20        1074 non-null   float64
#  23  Rating 30        1074 non-null   float64
#  24  Rating 40        1074 non-null   float64
#  25  Rating 50        1074 non-null   float64
#  26  Rating 60        923 non-null    float64
#  27  Rating 70        759 non-null    float64
#  28  Rating 80        590 non-null    float64
#  29  Rating 90        389 non-null    float64
#  30  Rating 100       215 non-null    float64
#  31  Rating Rank      626 non-null    object
#  32  Popularity Rank  359 non-null    object
#  33  Related 1        1462 non-null   object
#  34  Related 1 Type   1462 non-null   object
#  35  Related 2        658 non-null    object
#  36  Related 2 Type   658 non-null    object
#  37  Name Word Count  2436 non-null   float64
# dtypes: float64(15), object(23)
# memory usage: 742.2+ KB
